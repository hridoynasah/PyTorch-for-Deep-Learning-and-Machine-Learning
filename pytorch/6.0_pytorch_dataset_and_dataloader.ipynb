# %%
from sklearn.datasets import make_classification

# create custom classification dataset
X, y = make_classification(
    n_samples=100,
    n_features=5,
    n_informative=5,
    n_redundant=0,
    n_classes=3
)

# %%
print(X[:4]); print(); print(X.shape)
# Out:
# [[-0.66908547  0.1965899   2.32451917 -2.32147356  0.34729516]
#  [-1.12867475  1.59393101  1.4965773  -1.32763045 -0.43884541]
#  [-2.94375137 -1.29122747  2.88149092  3.47214077  1.71858626]
#  [-0.03397882  1.74742965 -0.59531995  0.72239527  0.50992799]]
#
# (100, 5)

# %%
print(y[:5]); print(); print(y.shape)
# Out:
# [0 0 1 0 1]
#
# (100,)

# %%
# Convert numpy array to pytorch tensor
import torch
X_train = torch.tensor(X, dtype=torch.float32)
y_train = torch.tensor(y, dtype=torch.long)

# %%
print(X_train[:4])
# Out:
# tensor([[-0.6691,  0.1966,  2.3245, -2.3215,  0.3473],
#         [-1.1287,  1.5939,  1.4966, -1.3276, -0.4388],
#         [-2.9438, -1.2912,  2.8815,  3.4721,  1.7186],
#         [-0.0340,  1.7474, -0.5953,  0.7224,  0.5099]])

# %%
print(y_train[:4])
# Out:
# tensor([0, 0, 1, 0])

# %%
# Now create our custom dataset
from torch.utils.data import Dataset, DataLoader

class CustomDataset(Dataset):

    def __init__(self, features, labels):
        self.features = features
        self.labels = labels

    def __len__(self):
        return self.features.shape[0]

    def __getitem__(self, index):
        return self.features[index], self.labels[index]

# %%
dataset = CustomDataset(X_train, y_train)

# %%
print(len(dataset))
# Out:
# 100

# %%
dataLoader = DataLoader(
    dataset,
    batch_size=5,
    shuffle=True
)

# %%
for batch_features, batch_labels in dataLoader:
    print(batch_features)
    print(batch_labels)
    print("--" * 50)
# Out:
# tensor([[ 0.3953,  2.2995, -1.4151, -0.3909,  1.3512],
#         [ 0.5605,  2.5458, -0.1730,  1.3082,  1.0443],
#         [-2.9438, -1.2912,  2.8815,  3.4721,  1.7186],
#         [-0.9527,  1.4476, -0.7587,  1.2500,  0.6926],
#         [-0.0340,  1.7474, -0.5953,  0.7224,  0.5099]])
# tensor([1, 1, 1, 0, 0])
# ----------------------------------------------------------------------------------------------------
# tensor([[-1.8183, -0.2084,  0.6239,  2.1716,  1.7458],
#         [-1.7132,  0.9766,  1.5886,  1.5415,  0.9865],
#         [-1.2200, -0.8856,  0.1396,  1.0314, -1.4111],
#         [ 0.3658,  2.7777,  2.7708, -1.4847,  0.0454],
#         [-0.8056,  0.2304,  1.6330, -1.7456, -1.3405]])
# tensor([1, 1, 1, 0, 0])
# ----------------------------------------------------------------------------------------------------
# tensor([[-0.5739,  1.7993,  0.4199,  0.0133, -1.2105],
#         [-1.0051,  1.3958,  0.5648,  1.1580,  0.2248],
#         [-1.2664,  0.0077,  0.4159,  1.1699, -0.5481],
#         [ 0.3760, -1.3957, -0.9183, -0.6783,  0.5469],
#         [-1.3498,  1.1318,  0.4857, -0.1296, -1.1092]])
# tensor([0, 0, 1, 2, 0])
# ----------------------------------------------------------------------------------------------------
# tensor([[-1.4544,  1.0275, -0.8117, -0.9815, -1.1437],
#         [ 0.9018,  2.4207,  2.5575, -1.6378, -0.2082],
#         [-2.4724,  1.8259, -1.5258,  1.0127, -0.9159],
#         [-0.8117,  2.2661, -2.3837, -2.3767, -0.9387],
#         [ 0.8195, -0.5556, -1.2192, -1.3147, -0.0729]])
# tensor([1, 0, 0, 1, 2])
# ----------------------------------------------------------------------------------------------------
# tensor([[-1.9291,  2.6568,  0.8255,  1.2111, -3.0423],
#         [-1.1287,  1.5939,  1.4966, -1.3276, -0.4388],
#         [-3.2003,  1.3991, -1.7763,  3.2692,  1.5394],
#         [ 0.1513, -1.9304, -1.9628, -1.6507, -1.0464],
#         [-4.3229,  1.0122,  0.2379, -1.9181, -2.4445]])
# tensor([0, 0, 0, 2, 1])
# ----------------------------------------------------------------------------------------------------
# tensor([[-0.6691,  0.1966,  2.3245, -2.3215,  0.3473],
#         [ 2.6060, -0.0062, -0.6494, -1.8703,  2.6390],
#         [-1.1887, -0.9102, -0.9027,  2.5294, -2.0263],
#         [-0.5458, -2.6237, -2.4458, -1.6236, -2.6874],
#         [ 0.8015,  1.5121,  3.4137, -0.7465,  1.2189]])
# tensor([0, 2, 1, 2, 1])
# ----------------------------------------------------------------------------------------------------
# tensor([[-0.9762,  0.6778,  0.4539, -0.8149, -1.4658],
#         [-0.7277, -2.8462, -1.2076,  1.2180, -1.6735],
#         [-0.0598, -0.6133, -0.7753, -0.8036, -2.2745],
#         [-0.4724,  2.4417, -0.3411,  0.5095,  1.4665],
#         [-1.3540, -0.5101,  2.8995,  0.8363, -1.9772]])
# tensor([0, 2, 0, 1, 1])
# ----------------------------------------------------------------------------------------------------
# tensor([[-1.7403e+00,  1.8129e+00,  1.7375e+00,  1.2972e+00,  4.7455e-01],
#         [ 3.2539e-01,  9.0182e-01, -8.8999e-01,  1.3994e+00,  1.9878e+00],
#         [-2.3879e+00,  3.3619e+00,  2.4553e+00, -7.0198e-01,  9.9839e-01],
#         [-2.6491e+00,  3.4364e-01, -2.4644e+00,  2.0842e+00,  2.8996e+00],
#         [-2.3332e+00,  1.4816e+00, -4.8219e-01, -3.2516e-03, -1.3006e+00]])
# tensor([1, 0, 0, 0, 1])
# ----------------------------------------------------------------------------------------------------
# tensor([[-1.7034,  1.5118, -1.3966, -2.2613, -1.2265],
#         [ 3.3072, -0.9093, -0.8035, -0.4563, -0.7654],
#         [ 4.3839,  1.0595, -1.5765, -2.0665,  1.3559],
#         [-1.8658,  0.1055, -2.3633, -0.2682, -0.1772],
#         [ 0.2463, -1.1025, -1.5627, -0.8035, -0.1660]])
# tensor([1, 2, 2, 0, 2])
# ----------------------------------------------------------------------------------------------------
# tensor([[ 3.3120, -0.8516, -0.2085, -2.6456,  0.1135],
#         [-1.4077, -0.9966, -0.3301, -1.0679, -2.3944],
#         [ 2.9925, -0.1216, -1.3892, -1.4300,  2.3969],
#         [-3.5506,  1.9237, -0.7398, -1.9043, -1.6225],
#         [-1.1243, -1.2004, -1.9314, -0.2308,  1.4227]])
# tensor([2, 0, 2, 1, 0])
# ----------------------------------------------------------------------------------------------------
# tensor([[ 0.2685,  1.2943,  1.7779, -1.9259,  0.6376],
#         [ 0.0995, -1.2931, -2.0809, -0.5406, -0.3174],
#         [ 2.3977, -0.5018, -0.2400, -1.0081,  0.6437],
#         [ 0.3506, -1.8951, -0.0342, -0.3509,  1.1871],
#         [-1.7667,  0.7169,  0.5989,  0.9808, -1.0386]])
# tensor([0, 2, 2, 2, 1])
# ----------------------------------------------------------------------------------------------------
# tensor([[-0.8396,  1.1472,  0.3222, -0.5415, -1.2970],
#         [ 2.6334,  1.0350,  1.1471,  0.0491, -1.3090],
#         [ 0.9163, -1.4532, -0.9652, -2.6080, -1.6138],
#         [-0.8688, -2.5090, -2.0726, -2.6382, -1.8716],
#         [-0.8198, -2.3160, -2.5214,  0.1668, -2.2040]])
# tensor([0, 2, 2, 2, 2])
# ----------------------------------------------------------------------------------------------------
# tensor([[ 0.7531, -0.7812, -1.1691, -0.9582, -0.4091],
#         [ 1.8212, -1.1809, -1.2827, -1.9341, -0.1168],
#         [ 1.7144, -0.2257, -1.8827, -1.3813,  0.3629],
#         [-0.9777,  0.8362,  0.1009,  0.5424, -0.4904],
#         [-1.2105, -1.2366,  1.2964,  1.2333, -0.5079]])
# tensor([2, 2, 2, 1, 1])
# ----------------------------------------------------------------------------------------------------
# tensor([[-0.1687, -0.8873, -1.4082,  1.1751, -1.8425],
#         [ 3.1787,  2.0146,  1.9511,  0.0632, -0.2450],
#         [ 0.8278,  0.0091,  0.5265, -0.5483, -2.8618],
#         [ 0.0689, -2.6674,  0.8220,  0.7844, -0.5802],
#         [ 2.4346, -0.1963,  0.1252, -0.4375, -1.6209]])
# tensor([2, 2, 2, 2, 2])
# ----------------------------------------------------------------------------------------------------
# tensor([[-0.3189, -0.3667, -0.7399,  1.3276, -1.1806],
#         [-2.8071,  0.4212, -1.3943,  0.9573, -3.0329],
#         [ 2.6483, -0.1386, -0.7475, -1.7353,  2.3461],
#         [ 0.3298, -0.2163, -0.1506, -0.4912, -1.4714],
#         [ 1.0156,  2.1536, -2.0882, -1.2960,  0.6279]])
# tensor([1, 0, 2, 1, 1])
# ----------------------------------------------------------------------------------------------------
# tensor([[ 1.4568, -0.3366, -1.1451,  1.7038, -0.0440],
#         [-0.6375,  1.6130, -1.5361, -3.9151, -0.7019],
#         [-0.5813,  3.2173,  0.2911,  0.2072,  1.3024],
#         [ 0.9791,  2.5576,  1.8402,  0.6858, -0.5479],
#         [-0.8653, -0.6154,  0.3760,  1.1706,  0.8000]])
# tensor([1, 1, 1, 0, 1])
# ----------------------------------------------------------------------------------------------------
# tensor([[-1.1830, -3.8640,  1.4016,  1.5011,  0.1541],
#         [-1.3646, -0.1684,  2.8148,  1.2982, -0.2120],
#         [-3.1805,  1.8141, -0.2126,  0.1220, -0.7436],
#         [-2.5589,  0.0696, -0.8487,  1.4147,  1.3622],
#         [-0.4207,  0.6074, -0.3654, -0.0923, -0.8699]])
# tensor([2, 1, 0, 0, 1])
# ----------------------------------------------------------------------------------------------------
# tensor([[ 0.1630,  1.8113,  3.5080,  0.1888,  2.5548],
#         [ 2.0571, -0.7674, -1.1785, -1.0945,  1.8091],
#         [-1.5261, -0.0256, -0.9349, -0.1773, -2.1983],
#         [-0.4463,  1.5469, -3.9194,  2.1246,  5.6533],
#         [-1.7669, -0.6998, -3.4544,  0.1237,  2.1295]])
# tensor([1, 2, 0, 0, 0])
# ----------------------------------------------------------------------------------------------------
# tensor([[ 1.3704,  3.9196,  1.2636, -1.4048,  2.5810],
#         [ 1.2004,  0.5189, -1.7346, -2.8668, -0.5511],
#         [ 2.3314, -1.0468, -0.4700, -2.0542, -0.6256],
#         [ 1.3293, -1.7203,  0.5227, -0.7252,  2.8861],
#         [-0.0050,  2.1181,  1.3638, -1.0200,  0.0986]])
# tensor([1, 1, 2, 2, 0])
# ----------------------------------------------------------------------------------------------------
# tensor([[ 2.8093, -0.8398, -0.8699,  0.4320,  0.0990],
#         [ 0.3456, -0.1311, -0.6017,  0.4003, -1.4462],
#         [-1.6065,  2.8371,  2.4566, -0.7012,  1.0337],
#         [ 1.8827, -1.8553,  0.7754, -0.0456,  1.6162],
#         [-1.2867, -0.0933, -1.0913, -0.7991, -1.0668]])
# tensor([1, 2, 0, 2, 0])
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ### **Joss**
