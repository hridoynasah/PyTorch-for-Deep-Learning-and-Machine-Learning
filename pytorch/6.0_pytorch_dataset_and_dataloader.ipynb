# %%
from sklearn.datasets import make_classification

# create custom classification dataset
X, y = make_classification(
    n_samples=100,
    n_features=5,
    n_informative=5,
    n_redundant=0,
    n_classes=3
)

# %%
print(X[:4]); print(); print(X.shape)
# Out:
# [[ 0.31295794  1.08838527 -0.80163483  0.33515134  1.07489266]
#  [-0.03806003 -0.34921843 -2.80981522 -3.51861763 -1.80040764]
#  [-0.93074383  1.71560387  0.1444574  -1.68081544  1.33434285]
#  [ 0.78478791 -2.35029224  1.76015616  2.48997865  1.67067319]]
#
# (100, 5)

# %%
print(y[:5]); print(); print(y.shape)
# Out:
# [1 2 0 0 0]
#
# (100,)

# %%
# Convert numpy array to pytorch tensor
import torch
X_train = torch.tensor(X, dtype=torch.float32)
y_train = torch.tensor(y, dtype=torch.long)

# %%
print(X_train[:4])
# Out:
# tensor([[ 0.3130,  1.0884, -0.8016,  0.3352,  1.0749],
#         [-0.0381, -0.3492, -2.8098, -3.5186, -1.8004],
#         [-0.9307,  1.7156,  0.1445, -1.6808,  1.3343],
#         [ 0.7848, -2.3503,  1.7602,  2.4900,  1.6707]])

# %%
print(y_train[:4])
# Out:
# tensor([1, 2, 0, 0])

# %%
# Now create our custom dataset
from torch.utils.data import Dataset, DataLoader

class CustomDataset(Dataset):

    def __init__(self, features, labels):
        self.features = features
        self.labels = labels

    def __len__(self):
        return self.features.shape[0]

    def __getitem__(self, index):
        return self.features[index], self.labels[index]

# %%
dataset = CustomDataset(X_train, y_train)

# %%
print(len(dataset))
# Out:
# 100

# %%
dataLoader = DataLoader(
    dataset,
    batch_size=5,
    shuffle=True
)

# %%
for batch_features, batch_labels in dataLoader:
    print(batch_features)
    print(batch_labels)
    print("-" * 60)
# Out:
# tensor([[ 1.7064, -0.5429,  0.3804, -1.8054, -0.1801],
#         [ 0.9438,  1.3105,  0.2398, -0.4022, -1.1473],
#         [-2.5340,  0.6960, -2.1478,  0.4456,  1.4277],
#         [ 1.9475, -1.2192, -1.9107, -5.7112, -0.5817],
#         [-0.4083,  2.0467,  0.6026, -2.1528,  2.7736]])
# tensor([0, 2, 0, 0, 0])
# ------------------------------------------------------------
# tensor([[ 0.7848, -2.3503,  1.7602,  2.4900,  1.6707],
#         [ 0.8421, -0.7365,  1.1758, -1.6590,  0.6603],
#         [ 1.2062, -1.6272,  1.6323,  0.7129,  2.1320],
#         [-1.4872, -0.9793, -0.8400,  1.6811,  0.5549],
#         [ 1.0513,  0.2043, -2.8430, -3.7137, -0.9366]])
# tensor([0, 0, 0, 1, 2])
# ------------------------------------------------------------
# tensor([[ 1.5402, -1.4023,  0.4009, -1.3361,  0.9540],
#         [-1.0333,  1.1465, -4.0218,  1.2609, -3.2467],
#         [-0.0049, -0.1977, -0.0948,  2.1375,  0.0546],
#         [ 0.1988,  0.9918,  1.3893, -1.5579,  0.5255],
#         [ 0.0335,  1.5424,  3.3761, -0.2720,  1.6022]])
# tensor([0, 2, 0, 1, 0])
# ------------------------------------------------------------
# tensor([[ 2.1115,  0.7243,  0.0514,  0.7760,  0.3448],
#         [ 1.1199, -0.7029, -2.3399,  3.0953, -2.6887],
#         [ 1.8146,  2.2016,  1.2463,  1.6698,  1.5396],
#         [-1.2307, -1.1255, -1.2141,  0.2307, -2.2804],
#         [-0.9044,  0.5823, -0.7638, -0.8331, -2.6748]])
# tensor([2, 2, 1, 1, 2])
# ------------------------------------------------------------
# tensor([[ 2.3069,  2.3790,  1.4663,  0.6529, -0.4704],
#         [ 0.0239, -0.3269, -0.4560, -1.4673, -1.6334],
#         [ 1.8669,  1.9878, -0.1912, -0.8341, -0.6340],
#         [ 0.4291, -2.2038, -0.5463,  1.8765, -0.1516],
#         [-0.0774,  0.2676, -0.1274,  2.7835, -0.8369]])
# tensor([1, 2, 2, 1, 0])
# ------------------------------------------------------------
# tensor([[-1.1516, -1.7139, -1.9309,  1.2755, -1.7466],
#         [-1.2205, -2.2533, -1.8863,  1.8998, -1.1848],
#         [ 2.4924,  2.0131,  0.2650,  2.2352,  0.1710],
#         [ 1.9773,  0.9375, -1.0563, -0.9862, -0.0035],
#         [ 0.3130,  1.0884, -0.8016,  0.3352,  1.0749]])
# tensor([1, 1, 1, 2, 1])
# ------------------------------------------------------------
# tensor([[ 2.5305, -0.7633, -0.4320,  0.7511, -2.9969],
#         [-1.1930, -1.7982, -2.2754,  2.0357,  0.6074],
#         [-0.0395,  1.6809, -0.6676, -0.3977, -2.2588],
#         [-0.2955, -3.5226, -1.6994,  3.2723, -0.3714],
#         [ 0.1773, -3.6241, -0.9666,  2.9268, -0.8258]])
# tensor([1, 1, 2, 1, 1])
# ------------------------------------------------------------
# tensor([[ 1.1126,  1.3835,  2.4648, -2.2043, -2.7143],
#         [ 1.8295,  1.2812,  1.8080, -0.6778, -1.0593],
#         [-0.2217, -3.0430, -1.6798,  2.5861,  0.3621],
#         [-0.1007, -1.8583, -1.2292, -2.2284, -1.5619],
#         [-1.3823, -0.0578,  0.0099, -2.2472, -0.2881]])
# tensor([1, 1, 1, 1, 2])
# ------------------------------------------------------------
# tensor([[ 2.2850,  0.0837, -2.8826, -2.4403,  0.5680],
#         [ 2.1121,  2.0173,  1.1193,  0.8315,  1.7591],
#         [-0.7688, -1.3620,  1.8449, -1.4576, -0.7848],
#         [ 0.6918, -3.5080,  0.2902,  0.5089,  0.4231],
#         [ 0.4666, -4.4057, -0.7133,  5.5382,  2.6989]])
# tensor([2, 1, 0, 2, 1])
# ------------------------------------------------------------
# tensor([[-1.7890, -0.7039, -0.4936, -2.4595,  0.0801],
#         [ 1.1414, -1.2552,  1.0731, -1.0930,  0.9365],
#         [ 0.1110,  0.6108,  0.9849,  0.0235,  0.0987],
#         [-0.3132, -0.3493,  0.3795,  0.9128, -0.2736],
#         [ 1.9850, -4.2632, -2.5485, -2.8079, -0.9494]])
# tensor([2, 0, 0, 1, 0])
# ------------------------------------------------------------
# tensor([[-0.4160, -1.5664, -1.1382, -0.4012, -1.4195],
#         [ 0.3505, -2.3990,  1.1719, -0.6844,  0.1025],
#         [-1.9887, -3.8152, -0.0240, -3.3430,  0.1993],
#         [ 1.2547,  1.2897, -1.4711, -1.8000, -0.9529],
#         [ 0.5006,  2.1095,  3.1358, -2.6966, -0.7491]])
# tensor([2, 2, 2, 2, 1])
# ------------------------------------------------------------
# tensor([[-7.5955e-01, -8.6169e-01, -4.4719e-01,  1.0992e+00, -5.4384e-01],
#         [ 6.4207e-01,  1.6367e-01,  1.8558e+00, -5.5092e-01,  2.0865e+00],
#         [-9.3074e-01,  1.7156e+00,  1.4446e-01, -1.6808e+00,  1.3343e+00],
#         [ 1.6282e+00,  3.1637e+00, -1.0475e+00, -1.5617e+00, -1.2906e+00],
#         [-5.5057e-01, -1.3244e+00, -8.1869e-01, -3.9364e-04, -2.3478e+00]])
# tensor([1, 0, 0, 2, 1])
# ------------------------------------------------------------
# tensor([[-0.5922,  2.2205, -0.9638, -0.1265,  0.4860],
#         [-1.5016,  2.5740, -0.6653, -1.6363,  3.3282],
#         [ 1.7904,  0.7664,  1.1899, -2.7825,  2.2652],
#         [-1.5893, -1.4864,  0.0110, -3.3078, -0.7612],
#         [-1.2836, -1.5952, -2.2077,  2.3244,  0.5482]])
# tensor([0, 0, 0, 2, 1])
# ------------------------------------------------------------
# tensor([[ 0.3674, -1.5468, -2.0738,  0.1615, -1.8211],
#         [ 0.8548,  0.3031, -0.4087, -0.5648, -0.0708],
#         [-1.5234,  2.2336, -4.6686,  1.8453,  3.1970],
#         [ 1.7829, -0.2175,  0.5961, -2.3052,  1.3183],
#         [ 0.7506,  1.3306,  0.3807,  2.4576, -0.7752]])
# tensor([1, 1, 0, 0, 0])
# ------------------------------------------------------------
# tensor([[-0.1576,  2.2481, -1.6976,  1.5557,  1.3062],
#         [-0.9983, -0.4654,  1.1429, -1.3473, -0.7429],
#         [-2.1066, -0.5405, -1.5574,  1.3258,  1.0694],
#         [ 2.2479, -0.0564, -1.4178, -2.2846,  0.3878],
#         [-1.5636,  0.2761, -1.3668, -1.7827, -1.8648]])
# tensor([0, 0, 0, 2, 2])
# ------------------------------------------------------------
# tensor([[-0.5098, -0.9380, -0.6329,  4.1703, -1.0217],
#         [ 0.9652, -1.4922,  1.3130,  0.3843,  1.0996],
#         [ 0.1985, -2.6547,  1.4251, -1.4296,  0.5640],
#         [ 2.3259,  2.4653, -3.5994, -2.8510, -0.3770],
#         [ 2.5725,  2.2593, -1.6163, -1.7271,  0.0269]])
# tensor([0, 0, 2, 2, 2])
# ------------------------------------------------------------
# tensor([[-8.8308e-01,  4.5396e-02, -1.6513e+00, -1.6937e-01, -1.4881e+00],
#         [-9.0337e-01, -1.5924e+00, -1.6888e+00,  1.5260e+00, -3.6025e-01],
#         [-1.4172e+00, -1.4354e+00, -2.0075e+00, -3.3958e-01, -1.3378e+00],
#         [ 5.2169e-01, -5.8976e-01, -1.1184e+00, -6.1731e-01, -7.7280e-04],
#         [-1.3809e+00, -1.5987e+00, -4.2080e-01, -4.2171e+00, -4.7399e+00]])
# tensor([2, 1, 2, 1, 1])
# ------------------------------------------------------------
# tensor([[-1.4939, -1.9796, -1.4842, -3.0456, -1.3540],
#         [ 2.4177,  2.9944, -0.7663, -0.1675, -0.2576],
#         [-0.6875, -2.4764,  2.1086, -2.5016,  1.7803],
#         [ 0.0134, -2.6468, -0.4407,  1.7839, -1.0536],
#         [-2.5268, -0.6482, -2.2004, -1.7384, -1.0195]])
# tensor([1, 2, 2, 1, 2])
# ------------------------------------------------------------
# tensor([[-5.2067e-01, -1.6985e-03, -1.7488e+00,  7.8669e-01, -6.2279e-01],
#         [ 9.8776e-01, -6.8512e-01,  1.5409e+00, -5.5793e-01,  2.2212e+00],
#         [ 1.0926e+00,  1.9093e+00,  2.4234e-01,  1.7187e+00, -3.3923e-01],
#         [-7.7437e-01,  1.9460e+00, -9.2145e-01, -1.6994e-02,  1.8913e+00],
#         [-7.2139e-02, -1.1270e+00,  2.6209e+00,  2.5750e+00,  1.3544e+00]])
# tensor([2, 0, 0, 0, 0])
# ------------------------------------------------------------
# tensor([[-0.0381, -0.3492, -2.8098, -3.5186, -1.8004],
#         [-0.5015,  0.3331,  0.5677,  0.2352, -0.5455],
#         [-2.9106,  1.2018, -1.8852, -0.3158,  2.5843],
#         [ 1.8143,  2.8405,  0.9841,  1.1612, -0.7465],
#         [-3.3920,  4.2782, -3.8189, -2.1306,  3.3504]])
# tensor([2, 1, 0, 2, 0])
# ------------------------------------------------------------

# %% [markdown]
# ### **Joss**
